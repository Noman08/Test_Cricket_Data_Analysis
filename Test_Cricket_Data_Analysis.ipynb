# %%
## https://www.espncricinfo.com/records/highest-career-batting-average-282910

# %%
import pandas as pd

# %%
#import csv

# %%
df = pd.read_csv('CricketTestMatchData.csv')

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   14    24   3  1316  182*  62.66   2063
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 61   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 62  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 63  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 64    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 65   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50     0    4s  6s
# 0   58.60   29  13   7.0  626+   6
# 1   63.79    5   5   NaN   137  24
# 2   55.68    5   4   2.0   186   5
# 3   54.48    7  11   1.0  246+  11
# 4   56.00   10   5   2.0  104+   1
# ..    ...  ...  ..   ...   ...  ..
# 61  49.16   15  33   4.0  525+  23
# 62  59.67   27  38  11.0  1165  24
# 63  44.77    7   6   1.0  119+   0
# 64  60.02    6  13   4.0  241+  5+
# 65  25.59    1  10   2.0   53+   0
#
# [66 rows x 15 columns]

# %%
#rename Multiple Columns in a list

# %%
df = df.rename( columns = {'Mat':'Matches','NO':'Not_outs', 'HS':'Highest_Inns_Score', 'BF':'Balls_Faced', 'SR':'Batting_Strike_Rate'})

# %%
df.head(6)
# Out:
#               Player       Span  Matches  Inns  Not_outs  Runs  \
# 0   DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1   PHKD Mendis (SL)  2022-2025       14    24         3  1316
# 2     AC Voges (AUS)  2015-2016       20    31         7  1485
# 3    RG Pollock (SA)  1963-1970       23    41         4  2256
# 4    GA Headley (WI)  1930-1954       22    40         4  2190
# 5  H Sutcliffe (ENG)  1924-1935       54    84         9  4555
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50    0  \
# 0                334  99.94       9800+                58.60   29  13  7.0
# 1               182*  62.66        2063                63.79    5   5  NaN
# 2               269*  61.87        2667                55.68    5   4  2.0
# 3                274  60.97       1707+                54.48    7  11  1.0
# 4               270*  60.83        416+                56.00   10   5  2.0
# 5                194  60.73       6558+                34.59   16  23  2.0
#
#      4s  6s
# 0  626+   6
# 1   137  24
# 2   186   5
# 3  246+  11
# 4  104+   1
# 5  202+   6

# %%
#Check Null Values

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# Not_outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate     True
# 100                    False
# 50                     False
# 0                       True
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#                   Player       Span  Matches  Inns  Not_outs  Runs  \
# 9         ED Weekes (WI)  1948-1958       48    81         5  4455
# 15       CL Walcott (WI)  1948-1960       44    74         7  3798
# 58  Hon.FS Jackson (ENG)  1893-1905       20    33         4  1415
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50    0  \
# 9                 207  58.61         NaN                  NaN   15  19  6.0
# 15                220  56.68         NaN                  NaN   15  14  1.0
# 58               144*  48.79         NaN                  NaN    5   6  3.0
#
#       4s  6s
# 9   258+   2
# 15  107+  11
# 58   51+   0

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df['Batting_Strike_Rate'] = df['Batting_Strike_Rate'].fillna(0)

# %%
df[df['Player'] == 'ED Weekes (WI)']
# Out:
#            Player       Span  Matches  Inns  Not_outs  Runs  \
# 9  ED Weekes (WI)  1948-1958       48    81         5  4455
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50    0  \
# 9                207  58.61           0                  0.0   15  19  6.0
#
#      4s 6s
# 9  258+  2

# %%
#drop duplicate

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# Length: 66, dtype: bool

# %%
df[df['Player'].duplicated() == 1]
# Out:
#                  Player       Span  Matches  Inns  Not_outs   Runs  \
# 8   KF Barrington (ENG)  1955-1968       82   131        15   6806
# 39       SR Waugh (AUS)  1985-2004      168   260        46  10927
# 57       JL Smith (ENG)  2024-2025       15    25         3   1075
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50     0  \
# 8                 256  58.67       4957+                42.42   20  35   5.0
# 39                200  51.06       22461                48.64   32  50  22.0
# 57               184*  48.86        1429                75.22    2   6   NaN
#
#       4s  6s
# 8   591+  27
# 39  1175  20
# 57   111  26

# %%
df[df['Player'].isin(['KF Barrington (ENG)', 'SR Waugh (AUS)', 'JL Smith (ENG)'])]
# Out:
#                  Player       Span  Matches  Inns  Not_outs   Runs  \
# 7   KF Barrington (ENG)  1955-1968       82   131        15   6806
# 8   KF Barrington (ENG)  1955-1968       82   131        15   6806
# 38       SR Waugh (AUS)  1985-2004      168   260        46  10927
# 39       SR Waugh (AUS)  1985-2004      168   260        46  10927
# 56       JL Smith (ENG)  2024-2025       15    25         3   1075
# 57       JL Smith (ENG)  2024-2025       15    25         3   1075
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50     0  \
# 7                 256  58.67       4957+                42.42   20  35   5.0
# 8                 256  58.67       4957+                42.42   20  35   5.0
# 38                200  51.06       22461                48.64   32  50  22.0
# 39                200  51.06       22461                48.64   32  50  22.0
# 56               184*  48.86        1429                75.22    2   6   NaN
# 57               184*  48.86        1429                75.22    2   6   NaN
#
#       4s  6s
# 7   591+  27
# 8   591+  27
# 38  1175  20
# 39  1175  20
# 56   111  26
# 57   111  26

# %%
df = df.drop_duplicates()

# %%
df[df['Player'].isin(['KF Barrington (ENG)', 'SR Waugh (AUS)', 'JL Smith (ENG)'])]
# Out:
#                  Player       Span  Matches  Inns  Not_outs   Runs  \
# 7   KF Barrington (ENG)  1955-1968       82   131        15   6806
# 38       SR Waugh (AUS)  1985-2004      168   260        46  10927
# 56       JL Smith (ENG)  2024-2025       15    25         3   1075
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50     0  \
# 7                 256  58.67       4957+                42.42   20  35   5.0
# 38                200  51.06       22461                48.64   32  50  22.0
# 56               184*  48.86        1429                75.22    2   6   NaN
#
#       4s  6s
# 7   591+  27
# 38  1175  20
# 56   111  26

# %%
#split up Span into Start and End Date

# %%
df['Span'].str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2025]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 61    [1965, 1981]
# 62    [2002, 2014]
# 63    [1924, 1934]
# 64    [1930, 1938]
# 65    [1928, 1934]
# Name: Span, Length: 63, dtype: object

# %%
df['Rookie_Year'] = df['Span'].str.split(pat = '-').str[0]

# %%
df['Final_Year'] = df['Span'].str.split(pat = '-').str[1]

# %%
df
# Out:
#                Player       Span  Matches  Inns  Not_outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1    PHKD Mendis (SL)  2022-2025       14    24         3  1316
# 2      AC Voges (AUS)  2015-2016       20    31         7  1485
# 3     RG Pollock (SA)  1963-1970       23    41         4  2256
# 4     GA Headley (WI)  1930-1954       22    40         4  2190
# ..                ...        ...      ...   ...       ...   ...
# 61   KD Walters (AUS)  1965-1981       74   125        14  5357
# 62  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 63  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 64    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 65   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50     0  \
# 0                 334  99.94       9800+                58.60   29  13   7.0
# 1                182*  62.66        2063                63.79    5   5   NaN
# 2                269*  61.87        2667                55.68    5   4   2.0
# 3                 274  60.97       1707+                54.48    7  11   1.0
# 4                270*  60.83        416+                56.00   10   5   2.0
# ..                ...    ...         ...                  ...  ...  ..   ...
# 61                250  48.26       8662+                49.16   15  33   4.0
# 62                277  48.25       15525                59.67   27  38  11.0
# 63                266  48.22       3118+                44.77    7   6   1.0
# 64                232  48.21       3217+                60.02    6  13   4.0
# 65                127  48.00       2110+                25.59    1  10   2.0
#
#       4s  6s Rookie_Year Final_Year
# 0   626+   6        1928       1948
# 1    137  24        2022       2025
# 2    186   5        2015       2016
# 3   246+  11        1963       1970
# 4   104+   1        1930       1954
# ..   ...  ..         ...        ...
# 61  525+  23        1965       1981
# 62  1165  24        2002       2014
# 63  119+   0        1924       1934
# 64  241+  5+        1930       1938
# 65   53+   0        1928       1934
#
# [63 rows x 17 columns]

# %%
#Drop Span Columns

# %%
df = df.drop(['Span'], axis = 1)

# %%
df.head()
# Out:
#              Player  Matches  Inns  Not_outs  Runs Highest_Inns_Score    Ave  \
# 0  DG Bradman (AUS)       52    80        10  6996                334  99.94
# 1  PHKD Mendis (SL)       14    24         3  1316               182*  62.66
# 2    AC Voges (AUS)       20    31         7  1485               269*  61.87
# 3   RG Pollock (SA)       23    41         4  2256                274  60.97
# 4   GA Headley (WI)       22    40         4  2190               270*  60.83
#
#   Balls_Faced  Batting_Strike_Rate  100  50    0    4s  6s Rookie_Year  \
# 0       9800+                58.60   29  13  7.0  626+   6        1928
# 1        2063                63.79    5   5  NaN   137  24        2022
# 2        2667                55.68    5   4  2.0   186   5        2015
# 3       1707+                54.48    7  11  1.0  246+  11        1963
# 4        416+                56.00   10   5  2.0  104+   1        1930
#
#   Final_Year
# 0       1948
# 1       2025
# 2       2016
# 3       1970
# 4       1954

# %%
#changes DataTypes

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_outs                 int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                      float64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# dtype: object

# %%
df['Highest_Inns_Score'].str.split(pat = '*').str[0]
# Out:
# 0     334
# 1     182
# 2     269
# 3     274
# 4     270
#      ...
# 61    250
# 62    277
# 63    266
# 64    232
# 65    127
# Name: Highest_Inns_Score, Length: 63, dtype: object

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].str.split(pat = '*').str[0]

# %%
df['Highest_Inns_Score']
# Out:
# 0     334
# 1     182
# 2     269
# 3     274
# 4     270
#      ...
# 61    250
# 62    277
# 63    266
# 64    232
# 65    127
# Name: Highest_Inns_Score, Length: 63, dtype: object

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].astype('int')

# %%
df['Highest_Inns_Score']
# Out:
# 0     334
# 1     182
# 2     269
# 3     274
# 4     270
#      ...
# 61    250
# 62    277
# 63    266
# 64    232
# 65    127
# Name: Highest_Inns_Score, Length: 63, dtype: int64

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                      float64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# dtype: object

# %%
df['Balls_Faced'] = df['Balls_Faced'].str.split(pat = '+').str[0]

# %%
df[df['Balls_Faced'].isna() == 1]
# Out:
#                   Player  Matches  Inns  Not_outs  Runs  Highest_Inns_Score  \
# 9         ED Weekes (WI)       48    81         5  4455                 207
# 15       CL Walcott (WI)       44    74         7  3798                 220
# 58  Hon.FS Jackson (ENG)       20    33         4  1415                 144
#
#       Ave Balls_Faced  Batting_Strike_Rate  100  50    0    4s  6s  \
# 9   58.61         NaN                  0.0   15  19  6.0  258+   2
# 15  56.68         NaN                  0.0   15  14  1.0  107+  11
# 58  48.79         NaN                  0.0    5   6  3.0   51+   0
#
#    Rookie_Year Final_Year
# 9         1948       1958
# 15        1948       1960
# 58        1893       1905

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df['Balls_Faced'] = df['Balls_Faced'].astype('int')

# %%
df['4s'] = df['4s'].str.split(pat = '+').str[0]

# %%
df['4s'] = df['4s'].astype('int')

# %%
df['6s'] = df['6s'].str.split(pat = '+').str[0]
df['6s'] = df['6s'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced              int64
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                      float64
# 4s                       int64
# 6s                       int64
# Rookie_Year             object
# Final_Year              object
# dtype: object

# %%
df = df.astype({'Rookie_Year': 'int', 'Final_Year': 'int'})

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced              int64
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                      float64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int64
# Final_Year               int64
# dtype: object

# %%
## QUESTION Build out Carrer_Length Column

# %%
df['career_length'] = df['Final_Year'] - df['Rookie_Year']

# %%
df
# Out:
#                Player  Matches  Inns  Not_outs  Runs  Highest_Inns_Score  \
# 0    DG Bradman (AUS)       52    80        10  6996                 334
# 1    PHKD Mendis (SL)       14    24         3  1316                 182
# 2      AC Voges (AUS)       20    31         7  1485                 269
# 3     RG Pollock (SA)       23    41         4  2256                 274
# 4     GA Headley (WI)       22    40         4  2190                 270
# ..                ...      ...   ...       ...   ...                 ...
# 61   KD Walters (AUS)       74   125        14  5357                 250
# 62  GC Smith (ICC/SA)      117   205        13  9265                 277
# 63  WH Ponsford (AUS)       29    48         4  2122                 266
# 64    SJ McCabe (AUS)       39    62         5  2748                 232
# 65   DR Jardine (ENG)       22    33         6  1296                 127
#
#       Ave  Balls_Faced  Batting_Strike_Rate  100  50     0    4s  6s  \
# 0   99.94         9800                58.60   29  13   7.0   626   6
# 1   62.66         2063                63.79    5   5   NaN   137  24
# 2   61.87         2667                55.68    5   4   2.0   186   5
# 3   60.97         1707                54.48    7  11   1.0   246  11
# 4   60.83          416                56.00   10   5   2.0   104   1
# ..    ...          ...                  ...  ...  ..   ...   ...  ..
# 61  48.26         8662                49.16   15  33   4.0   525  23
# 62  48.25        15525                59.67   27  38  11.0  1165  24
# 63  48.22         3118                44.77    7   6   1.0   119   0
# 64  48.21         3217                60.02    6  13   4.0   241   5
# 65  48.00         2110                25.59    1  10   2.0    53   0
#
#     Rookie_Year  Final_Year  career_length
# 0          1928        1948             20
# 1          2022        2025              3
# 2          2015        2016              1
# 3          1963        1970              7
# 4          1930        1954             24
# ..          ...         ...            ...
# 61         1965        1981             16
# 62         2002        2014             12
# 63         1924        1934             10
# 64         1930        1938              8
# 65         1928        1934              6
#
# [63 rows x 17 columns]

# %%
## Calculations with dataframe

# %%
##Question 1 -> Cricketers in this DF what is the Average Career Length

# %%
df['career_length'].mean()
# Out:
# np.float64(12.80952380952381)

# %%
#Question 2 AVG Batting_Strike_Rate for cricketers who played over 10 years

# %%
df[df['career_length'] > 10]['Batting_Strike_Rate'].mean()
# Out:
# np.float64(47.805116279069765)

# %%
#Question 3 find number of cricketers who played before 1960

# %%
df[df['Rookie_Year'] < 1960 ]['Player'].count()
# Out:
# np.int64(23)

# %%
#Question 4 Max Highest Inns Score by country

# %%
df['Country'] = df['Player'].str.split(pat = '(').str[1].str.split(pat = ')').str[0]

# %%
df['Player'] = df['Player'].str.split(pat = '(').str[0]

# %%
df
# Out:
#           Player  Matches  Inns  Not_outs  Runs  Highest_Inns_Score    Ave  \
# 0    DG Bradman        52    80        10  6996                 334  99.94
# 1   PHKD Mendis        14    24         3  1316                 182  62.66
# 2      AC Voges        20    31         7  1485                 269  61.87
# 3    RG Pollock        23    41         4  2256                 274  60.97
# 4    GA Headley        22    40         4  2190                 270  60.83
# ..           ...      ...   ...       ...   ...                 ...    ...
# 61   KD Walters        74   125        14  5357                 250  48.26
# 62     GC Smith       117   205        13  9265                 277  48.25
# 63  WH Ponsford        29    48         4  2122                 266  48.22
# 64    SJ McCabe        39    62         5  2748                 232  48.21
# 65   DR Jardine        22    33         6  1296                 127  48.00
#
#     Balls_Faced  Batting_Strike_Rate  100  50     0    4s  6s  Rookie_Year  \
# 0          9800                58.60   29  13   7.0   626   6         1928
# 1          2063                63.79    5   5   NaN   137  24         2022
# 2          2667                55.68    5   4   2.0   186   5         2015
# 3          1707                54.48    7  11   1.0   246  11         1963
# 4           416                56.00   10   5   2.0   104   1         1930
# ..          ...                  ...  ...  ..   ...   ...  ..          ...
# 61         8662                49.16   15  33   4.0   525  23         1965
# 62        15525                59.67   27  38  11.0  1165  24         2002
# 63         3118                44.77    7   6   1.0   119   0         1924
# 64         3217                60.02    6  13   4.0   241   5         1930
# 65         2110                25.59    1  10   2.0    53   0         1928
#
#     Final_Year  career_length Country
# 0         1948             20     AUS
# 1         2025              3      SL
# 2         2016              1     AUS
# 3         1970              7      SA
# 4         1954             24      WI
# ..         ...            ...     ...
# 61        1981             16     AUS
# 62        2014             12  ICC/SA
# 63        1934             10     AUS
# 64        1938              8     AUS
# 65        1934              6     ENG
#
# [63 rows x 18 columns]

# %%
df.groupby('Country')['Highest_Inns_Score'].max().to_frame('Highinncountry').reset_index().sort_values('Highinncountry', ascending = False)
# Out:
#     Country  Highinncountry
# 5    ICC/WI             400
# 0       AUS             380
# 10       SL             374
# 11       WI             365
# 1       ENG             364
# 3   ICC/PAK             329
# 2   ICC/IND             319
# 8       PAK             313
# 9        SA             278
# 4    ICC/SA             277
# 7        NZ             251
# 6       IND             248
# 12      ZIM             232

# %%
#Question 5 Hundreds, Fifties, duck (0) AVG by Country

# %%
df.groupby('Country')[['100', '50', '0']].mean()
# Out:
#                100         50          0
# Country
# AUS      21.533333  29.066667   8.933333
# ENG      12.642857  20.571429   4.538462
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      23.750000  32.000000   8.500000
# NZ       33.000000  37.000000  11.000000
# PAK      17.800000  24.200000   8.000000
# SA        9.800000  20.200000   3.400000
# SL       22.750000  34.250000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
